# %% [markdown]
# # <span style="color:darkblue"> QTM 151 - Quiz 2 </span>

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size="5">
#
# Print your name below

# %%
# Write your answer here
print ("Daisy Cossio Garcia")
# Out:
# Daisy Cossio Garcia

# %% [markdown]
# <font size = "5" >
# This quiz is open book
#
# - You can use the lecture notes
# - You will get partial credit for attempting the questions
# - To get full credit, the code should run as intended
# - You should <span style="color:red"> NOT </span> communicate with other students
#
# Print the following message: <br>
#
# "I will abide by Emory's code of conduct"

# %%
# Write your answer here:

print ("I will abide by Emory code of conduct ")
# Out:
# I will abide by Emory code of conduct

# %% [markdown]
# <font size = "5">
#
# Import the libraries "numpy", "matplotlib.pyplot", and "pandas"

# %%
# Write your answer here
 
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

# %% [markdown]
# <font size = "5">
#
# Import the dataset "data_quiz/fifa23_players_basic.csv"
#
# - It's a dataset on professional soccer players
# - Rows correspond to players (18,539)
# - Columns contain attributes of players (32)
# - Try to view the dataset before starting

# %%
# Write your own code

Soccer = pd.read_csv("data_quiz/fifa23_players_basic.csv")
display(Soccer)
# Out:
#              Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0            L. Messi        Lionel Messi       91         91        54000000
# 1          K. Benzema       Karim Benzema       91         91        64000000
# 2      R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3        K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4           K. Mbappé       Kylian Mbappé       91         95       190500000
# ...               ...                 ...      ...        ...             ...
# 18534      D. Collins      Darren Collins       47         56          110000
# 18535    Yang Dejiang        Dejiang Yang       47         57           90000
# 18536       L. Mullan         Liam Mullan       47         67          130000
# 18537    D. McCallion    Daithí McCallion       47         61          100000
# 18538        N. Rabha         Nabin Rabha       47         50           60000
#
#       Positions Played Best Position          Nationality  \
# 0                   RW           CAM            Argentina
# 1                CF,ST            CF               France
# 2                   ST            ST               Poland
# 3               CM,CAM            CM              Belgium
# 4                ST,LW            ST               France
# ...                ...           ...                  ...
# 18534            ST,RM           CAM  Republic of Ireland
# 18535              CDM           CDM             China PR
# 18536               CM            RM     Northern Ireland
# 18537               CB            CB  Republic of Ireland
# 18538               LB            LB                India
#
#                                              Image Link  Age  ...  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png   35  ...
# 1      https://cdn.sofifa.net/players/165/153/23_60.png   34  ...
# 2      https://cdn.sofifa.net/players/188/545/23_60.png   33  ...
# 3      https://cdn.sofifa.net/players/192/985/23_60.png   31  ...
# 4      https://cdn.sofifa.net/players/231/747/23_60.png   23  ...
# ...                                                 ...  ...  ...
# 18534  https://cdn.sofifa.net/players/243/725/23_60.png   21  ...
# 18535  https://cdn.sofifa.net/players/261/933/23_60.png   17  ...
# 18536  https://cdn.sofifa.net/players/267/823/23_60.png   18  ...
# 18537  https://cdn.sofifa.net/players/267/824/23_60.png   17  ...
# 18538  https://cdn.sofifa.net/players/261/424/23_60.png   25  ...
#
#        Preferred Foot  Weak Foot Rating  Skill Moves  \
# 0                Left                 4            4
# 1               Right                 4            4
# 2               Right                 4            4
# 3               Right                 5            4
# 4               Right                 4            5
# ...               ...               ...          ...
# 18534           Right                 3            2
# 18535           Right                 3            2
# 18536           Right                 3            2
# 18537           Right                 3            2
# 18538            Left                 3            2
#
#        International Reputation National Team Name  \
# 0                             5          Argentina
# 1                             4             France
# 2                             5             Poland
# 3                             4            Belgium
# 4                             4             France
# ...                         ...                ...
# 18534                         1                  -
# 18535                         1                  -
# 18536                         1                  -
# 18537                         1                  -
# 18538                         1                  -
#
#                   National Team Image Link  National Team Position  \
# 0      https://cdn.sofifa.net/flags/ar.png                      RW
# 1      https://cdn.sofifa.net/flags/fr.png                      ST
# 2      https://cdn.sofifa.net/flags/pl.png                      ST
# 3      https://cdn.sofifa.net/flags/be.png                      RF
# 4      https://cdn.sofifa.net/flags/fr.png                      ST
# ...                                    ...                     ...
# 18534                                    -                       -
# 18535                                    -                       -
# 18536                                    -                       -
# 18537                                    -                       -
# 18538                                    -                       -
#
#       National Team Jersey Number Attacking Work Rate Defensive Work Rate
# 0                              10                 Low                 Low
# 1                              19              Medium              Medium
# 2                               9                High              Medium
# 3                               7                High                High
# 4                              10                High                 Low
# ...                           ...                 ...                 ...
# 18534                           -              Medium              Medium
# 18535                           -              Medium              Medium
# 18536                           -                High              Medium
# 18537                           -              Medium              Medium
# 18538                           -              Medium              Medium
#
# [18539 rows x 32 columns]

# %% [markdown]
# <font size = "5">
#
# (a) Create a function and apply it to a column <br>
#
# <font size = "3">
#
# Step 1:
# - Define a function with a parameter "age_player"
# - If "age_player < 20", status = "Less than 20"
# - If "age_player >= 20", status = "20 or older"
# - The function returns "status"
#
# Step 2:
# - Extract the column "Age" in the dataset <br>
# (be carefeful to write the "A" capitalized)
# - Create a new variable called "age_bracket" <br>
# to assign each player to the correct age bracket
#
# HINT: Use the ".apply()" function

# %%
# Write your own code

def fn_age (age_player): 
    if (age_player < 20 ):
        status = "Less than 20"
    else: 
        status = "20 or older"
    return(status)

Soccer ["age_player"] = Soccer ["Age"].apply(fn_age)

# %% [markdown]
# <font size = "5">
#
# (b) Use queries + global variables
#
# <font size = "3">
#
# - Compute the mean of the column "Value(in Euro)" <br>
# and store it as a variable
# - Subset the players whose value is above the mean value <br>
#   using ".query()"
#
#
# HINT: Remember that there is a special syntax for <br>
# when the column names have spaces (see Lecture 10) <br>
# Reference the column as ``` `Value(in Euro)`    ``` inside .query()

# %%
# Write your own code

subset = Soccer ["Value(in Euro)"]. mean()
subset
subset_Soccer = Soccer.query ("`Value(in Euro)` > 2875461.40")
display(subset_Soccer)
# Out:
#             Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0           L. Messi        Lionel Messi       91         91        54000000
# 1         K. Benzema       Karim Benzema       91         91        64000000
# 2     R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3       K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4          K. Mbappé       Kylian Mbappé       91         95       190500000
# ...              ...                 ...      ...        ...             ...
# 7066       F. Rieder       Fabian Rieder       68         83         2900000
# 7071     J. Bakayoko      Johan Bakayoko       68         85         3100000
# 7090        M. Arezo        Matías Arezo       68         81         2900000
# 7096       Y. Kallon        Yayah Kallon       68         82         3000000
# 7168        M. Soulé        Matías Soulé       68         85         3100000
#
#      Positions Played Best Position   Nationality  \
# 0                  RW           CAM     Argentina
# 1               CF,ST            CF        France
# 2                  ST            ST        Poland
# 3              CM,CAM            CM       Belgium
# 4               ST,LW            ST        France
# ...               ...           ...           ...
# 7066           CAM,CM           CAM   Switzerland
# 7071               RW            LM       Belgium
# 7090           ST,CAM            ST       Uruguay
# 7096         RM,RW,CF            ST  Sierra Leone
# 7168               RW            LM     Argentina
#
#                                             Image Link  Age  ...  \
# 0     https://cdn.sofifa.net/players/158/023/23_60.png   35  ...
# 1     https://cdn.sofifa.net/players/165/153/23_60.png   34  ...
# 2     https://cdn.sofifa.net/players/188/545/23_60.png   33  ...
# 3     https://cdn.sofifa.net/players/192/985/23_60.png   31  ...
# 4     https://cdn.sofifa.net/players/231/747/23_60.png   23  ...
# ...                                                ...  ...  ...
# 7066  https://cdn.sofifa.net/players/259/306/23_60.png   20  ...
# 7071  https://cdn.sofifa.net/players/265/450/23_60.png   19  ...
# 7090  https://cdn.sofifa.net/players/254/653/23_60.png   19  ...
# 7096  https://cdn.sofifa.net/players/262/333/23_60.png   21  ...
# 7168  https://cdn.sofifa.net/players/265/695/23_60.png   19  ...
#
#       Weak Foot Rating  Skill Moves  International Reputation  \
# 0                    4            4                         5
# 1                    4            4                         4
# 2                    4            4                         5
# 3                    5            4                         4
# 4                    4            5                         4
# ...                ...          ...                       ...
# 7066                 3            2                         1
# 7071                 3            3                         1
# 7090                 3            4                         1
# 7096                 2            3                         1
# 7168                 4            4                         1
#
#       National Team Name             National Team Image Link  \
# 0              Argentina  https://cdn.sofifa.net/flags/ar.png
# 1                 France  https://cdn.sofifa.net/flags/fr.png
# 2                 Poland  https://cdn.sofifa.net/flags/pl.png
# 3                Belgium  https://cdn.sofifa.net/flags/be.png
# 4                 France  https://cdn.sofifa.net/flags/fr.png
# ...                  ...                                  ...
# 7066                   -  https://cdn.sofifa.net/flags/ch.png
# 7071                   -  https://cdn.sofifa.net/flags/be.png
# 7090                   -  https://cdn.sofifa.net/flags/uy.png
# 7096                   -                                    -
# 7168                   -  https://cdn.sofifa.net/flags/ar.png
#
#       National Team Position  National Team Jersey Number Attacking Work Rate  \
# 0                         RW                           10                 Low
# 1                         ST                           19              Medium
# 2                         ST                            9                High
# 3                         RF                            7                High
# 4                         ST                           10                High
# ...                      ...                          ...                 ...
# 7066                       -                            -                High
# 7071                       -                            -                High
# 7090                       -                            -                High
# 7096                       -                            -                High
# 7168                       -                            -                High
#
#      Defensive Work Rate    age_player
# 0                    Low   20 or older
# 1                 Medium   20 or older
# 2                 Medium   20 or older
# 3                   High   20 or older
# 4                    Low   20 or older
# ...                  ...           ...
# 7066              Medium   20 or older
# 7071              Medium  Less than 20
# 7090              Medium  Less than 20
# 7096                 Low   20 or older
# 7168              Medium  Less than 20
#
# [3216 rows x 33 columns]

# %% [markdown]
# <font size = "5">
#
# (c) Use sorting + ".iloc[]"
#
# <font size = "3">
#
# - Use ".sort_values()" to order the "Age" column <br>
# from youngest to oldest
# - Get a subset with the 5 youngest players

# %%
# Write your own code

Soccersorted = Soccer.sort_values(by = "Age", ascending=True )
display(Soccersorted)

Five_Youngest_Players = display (Soccersorted.iloc[[0,1,2,3,4],:])
display(Five_Youngest_Players)
# Out:
#             Known As            Full Name  Overall  Potential  Value(in Euro)  \
# 17956     A. Dithmer      Andreas Dithmer       53         76          275000
# 18014      J. Ardila          José Ardila       53         73          250000
# 16084       S. Ngoma          Serge Ngoma       58         82          650000
# 11481      O. Vargas          Obed Vargas       64         81         1500000
# 17591  A. Madaliński      Alan Madaliński       54         68          210000
# ...              ...                  ...      ...        ...             ...
# 2423    Rubén Castro  Rubén Castro Martín       73         73               0
# 4499       G. Pegolo      Gianluca Pegolo       70         70          180000
# 3276      S. Torrico    Sebastián Torrico       72         72          250000
# 13548       S. Lukić         Stojan Lukić       62         62           45000
# 592        G. Buffon     Gianluigi Buffon       79         79         1900000
#
#       Positions Played Best Position             Nationality  \
# 17956               GK            GK                 Denmark
# 18014               CM           CAM               Venezuela
# 16084               RW            RM           United States
# 11481        CM,CDM,RM           CAM           United States
# 17591               GK            GK                  Poland
# ...                ...           ...                     ...
# 2423                ST            ST                   Spain
# 4499                GK            GK                   Italy
# 3276                GK            GK               Argentina
# 13548               GK            GK  Bosnia and Herzegovina
# 592                 GK            GK                   Italy
#
#                                              Image Link  Age  ...  \
# 17956  https://cdn.sofifa.net/players/269/573/23_60.png   16  ...
# 18014  https://cdn.sofifa.net/players/268/892/23_60.png   16  ...
# 16084  https://cdn.sofifa.net/players/267/796/23_60.png   16  ...
# 11481  https://cdn.sofifa.net/players/263/701/23_60.png   16  ...
# 17591  https://cdn.sofifa.net/players/270/590/23_60.png   16  ...
# ...                                                 ...  ...  ...
# 2423   https://cdn.sofifa.net/players/115/909/23_60.png   41  ...
# 4499   https://cdn.sofifa.net/players/106/795/23_60.png   41  ...
# 3276   https://cdn.sofifa.net/players/216/692/23_60.png   42  ...
# 13548  https://cdn.sofifa.net/players/213/483/23_60.png   42  ...
# 592    https://cdn.sofifa.net/players/001/179/23_60.png   44  ...
#
#        Weak Foot Rating  Skill Moves  International Reputation  \
# 17956                 2            1                         1
# 18014                 3            2                         1
# 16084                 3            2                         1
# 11481                 3            3                         1
# 17591                 3            1                         1
# ...                 ...          ...                       ...
# 2423                  3            3                         2
# 4499                  2            1                         1
# 3276                  2            1                         1
# 13548                 2            1                         1
# 592                   2            1                         4
#
#        National Team Name             National Team Image Link  \
# 17956                   -  https://cdn.sofifa.net/flags/dk.png
# 18014                   -  https://cdn.sofifa.net/flags/ve.png
# 16084                   -  https://cdn.sofifa.net/flags/us.png
# 11481                   -  https://cdn.sofifa.net/flags/us.png
# 17591                   -  https://cdn.sofifa.net/flags/pl.png
# ...                   ...                                  ...
# 2423                    -  https://cdn.sofifa.net/flags/es.png
# 4499                    -  https://cdn.sofifa.net/flags/it.png
# 3276                    -  https://cdn.sofifa.net/flags/ar.png
# 13548                   -                                    -
# 592                     -  https://cdn.sofifa.net/flags/it.png
#
#        National Team Position  National Team Jersey Number  \
# 17956                       -                            -
# 18014                       -                            -
# 16084                       -                            -
# 11481                       -                            -
# 17591                       -                            -
# ...                       ...                          ...
# 2423                        -                            -
# 4499                        -                            -
# 3276                        -                            -
# 13548                       -                            -
# 592                         -                            -
#
#       Attacking Work Rate Defensive Work Rate    age_player
# 17956              Medium              Medium  Less than 20
# 18014              Medium              Medium  Less than 20
# 16084                High              Medium  Less than 20
# 11481                High              Medium  Less than 20
# 17591              Medium              Medium  Less than 20
# ...                   ...                 ...           ...
# 2423               Medium                 Low   20 or older
# 4499               Medium              Medium   20 or older
# 3276               Medium              Medium   20 or older
# 13548              Medium              Medium   20 or older
# 592                Medium              Medium   20 or older
#
# [18539 rows x 33 columns]
#             Known As        Full Name  Overall  Potential  Value(in Euro)  \
# 17956     A. Dithmer  Andreas Dithmer       53         76          275000
# 18014      J. Ardila      José Ardila       53         73          250000
# 16084       S. Ngoma      Serge Ngoma       58         82          650000
# 11481      O. Vargas      Obed Vargas       64         81         1500000
# 17591  A. Madaliński  Alan Madaliński       54         68          210000
#
#       Positions Played Best Position    Nationality  \
# 17956               GK            GK        Denmark
# 18014               CM           CAM      Venezuela
# 16084               RW            RM  United States
# 11481        CM,CDM,RM           CAM  United States
# 17591               GK            GK         Poland
#
#                                              Image Link  Age  ...  \
# 17956  https://cdn.sofifa.net/players/269/573/23_60.png   16  ...
# 18014  https://cdn.sofifa.net/players/268/892/23_60.png   16  ...
# 16084  https://cdn.sofifa.net/players/267/796/23_60.png   16  ...
# 11481  https://cdn.sofifa.net/players/263/701/23_60.png   16  ...
# 17591  https://cdn.sofifa.net/players/270/590/23_60.png   16  ...
#
#        Weak Foot Rating  Skill Moves  International Reputation  \
# 17956                 2            1                         1
# 18014                 3            2                         1
# 16084                 3            2                         1
# 11481                 3            3                         1
# 17591                 3            1                         1
#
#        National Team Name             National Team Image Link  \
# 17956                   -  https://cdn.sofifa.net/flags/dk.png
# 18014                   -  https://cdn.sofifa.net/flags/ve.png
# 16084                   -  https://cdn.sofifa.net/flags/us.png
# 11481                   -  https://cdn.sofifa.net/flags/us.png
# 17591                   -  https://cdn.sofifa.net/flags/pl.png
#
#        National Team Position  National Team Jersey Number  \
# 17956                       -                            -
# 18014                       -                            -
# 16084                       -                            -
# 11481                       -                            -
# 17591                       -                            -
#
#       Attacking Work Rate Defensive Work Rate    age_player
# 17956              Medium              Medium  Less than 20
# 18014              Medium              Medium  Less than 20
# 16084                High              Medium  Less than 20
# 11481                High              Medium  Less than 20
# 17591              Medium              Medium  Less than 20
#
# [5 rows x 33 columns]
# None

# %% [markdown]
# <font size = "5">
#
# (d) Create a function with four inputs $f(y,x,b0,b1)$
#
# <font size = "3">
#
# $\qquad e2 = (y - b_0 - b_1 * x)^2$
#
# - The function should return the mean of e2
# - This is the mean-square error (mse)
# - Call the function "fn_mse"
# - Let $y$ be the column "Potential"
# - Let $x$ be the column "Age"
# - Does <br>
# $\qquad (b_0 = 80, b_1 = -1)$ or <br>
# $\qquad (b_0 = 80, b_1 =-0.4)$ or <br>
# $\qquad (b_0 = 80, b_1 = 1)$ <br>
# produce the lowest value of mse?

# %%
# Write your own code
e2 =np.e**2
def fn_mse(b0,b1):
    e2 = (y - b0 - b1 * x)**2 
    return (e2)

y = Soccer["Potential"]
x = Soccer["Age"]

f1 = fn_mse(b0= 80, b1= -1 )
f2 = fn_mse(b0= 80, b1= -0.4)
f3 = fn_mse(b0= 80, b1= 1)

print(f1)
print(f2)
print(f3)
# Out:
# 0        2116
# 1        2025
# 2        1936
# 3        1764
# 4        1444
#          ...
# 18534       9
# 18535      36
# 18536      25
# 18537       4
# 18538      25
# Length: 18539, dtype: int64
# 0        625.00
# 1        605.16
# 2        585.64
# 3        547.56
# 4        585.64
#           ...
# 18534    243.36
# 18535    262.44
# 18536     33.64
# 18537    148.84
# 18538    400.00
# Length: 18539, dtype: float64
# 0         576
# 1         529
# 2         484
# 3         400
# 4          64
#          ...
# 18534    2025
# 18535    1600
# 18536     961
# 18537    1296
# 18538    3025
# Length: 18539, dtype: int64

# %% [markdown]
# <font size = "5">
#
# (e) Split a dataset into subsets
#
# <font size = "3">
#
# - Create ``` list_status = [0,1]```
# - Create ``` list_prob = [0.5, 0.5]```
# - Create a new variable $n$ with the number of rows of the dataset
# - Use
# ```python
#     np.random.choice(list_status,
#                      size = n,
#                      p = list_prob)
# ```
# $\qquad$ to create a new column called "status" <br>
# $\qquad$ which randomly assigns each row to "0" or "1" <br>
# $\qquad$ with equal probability
# - Use .query() to subset all observations with status == 0.<br>
# store it in a new dataset called "data0"
# - Use .query() to subset all observations with status == 1.<br>
# store it in a new dataset called "data1"

# %%
# Write your own code

list_status = [0,1]
list_prob = [0.5, 0.5 ]
n = 18539
Soccer ["status"] = np.random.choice(list_status,
                                         size = n,
                                         p = list_prob)

display(Soccer)

data0 = Soccer.query('status == 0')
data1 = Soccer.query('status == 1')

display(data0.describe())
display(data1.describe())
# Out:
#              Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0            L. Messi        Lionel Messi       91         91        54000000
# 1          K. Benzema       Karim Benzema       91         91        64000000
# 2      R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3        K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4           K. Mbappé       Kylian Mbappé       91         95       190500000
# ...               ...                 ...      ...        ...             ...
# 18534      D. Collins      Darren Collins       47         56          110000
# 18535    Yang Dejiang        Dejiang Yang       47         57           90000
# 18536       L. Mullan         Liam Mullan       47         67          130000
# 18537    D. McCallion    Daithí McCallion       47         61          100000
# 18538        N. Rabha         Nabin Rabha       47         50           60000
#
#       Positions Played Best Position          Nationality  \
# 0                   RW           CAM            Argentina
# 1                CF,ST            CF               France
# 2                   ST            ST               Poland
# 3               CM,CAM            CM              Belgium
# 4                ST,LW            ST               France
# ...                ...           ...                  ...
# 18534            ST,RM           CAM  Republic of Ireland
# 18535              CDM           CDM             China PR
# 18536               CM            RM     Northern Ireland
# 18537               CB            CB  Republic of Ireland
# 18538               LB            LB                India
#
#                                              Image Link  Age  ...  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png   35  ...
# 1      https://cdn.sofifa.net/players/165/153/23_60.png   34  ...
# 2      https://cdn.sofifa.net/players/188/545/23_60.png   33  ...
# 3      https://cdn.sofifa.net/players/192/985/23_60.png   31  ...
# 4      https://cdn.sofifa.net/players/231/747/23_60.png   23  ...
# ...                                                 ...  ...  ...
# 18534  https://cdn.sofifa.net/players/243/725/23_60.png   21  ...
# 18535  https://cdn.sofifa.net/players/261/933/23_60.png   17  ...
# 18536  https://cdn.sofifa.net/players/267/823/23_60.png   18  ...
# 18537  https://cdn.sofifa.net/players/267/824/23_60.png   17  ...
# 18538  https://cdn.sofifa.net/players/261/424/23_60.png   25  ...
#
#        Skill Moves  International Reputation  National Team Name  \
# 0                4                         5           Argentina
# 1                4                         4              France
# 2                4                         5              Poland
# 3                4                         4             Belgium
# 4                5                         4              France
# ...            ...                       ...                 ...
# 18534            2                         1                   -
# 18535            2                         1                   -
# 18536            2                         1                   -
# 18537            2                         1                   -
# 18538            2                         1                   -
#
#                   National Team Image Link National Team Position  \
# 0      https://cdn.sofifa.net/flags/ar.png                     RW
# 1      https://cdn.sofifa.net/flags/fr.png                     ST
# 2      https://cdn.sofifa.net/flags/pl.png                     ST
# 3      https://cdn.sofifa.net/flags/be.png                     RF
# 4      https://cdn.sofifa.net/flags/fr.png                     ST
# ...                                    ...                    ...
# 18534                                    -                      -
# 18535                                    -                      -
# 18536                                    -                      -
# 18537                                    -                      -
# 18538                                    -                      -
#
#        National Team Jersey Number  Attacking Work Rate Defensive Work Rate  \
# 0                               10                  Low                 Low
# 1                               19               Medium              Medium
# 2                                9                 High              Medium
# 3                                7                 High                High
# 4                               10                 High                 Low
# ...                            ...                  ...                 ...
# 18534                            -               Medium              Medium
# 18535                            -               Medium              Medium
# 18536                            -                 High              Medium
# 18537                            -               Medium              Medium
# 18538                            -               Medium              Medium
#
#          age_player status
# 0       20 or older      0
# 1       20 or older      1
# 2       20 or older      0
# 3       20 or older      1
# 4       20 or older      1
# ...             ...    ...
# 18534   20 or older      1
# 18535  Less than 20      0
# 18536  Less than 20      1
# 18537  Less than 20      1
# 18538   20 or older      0
#
# [18539 rows x 34 columns]
#            Overall    Potential  Value(in Euro)          Age  Height(in cm)  \
# count  9296.000000  9296.000000    9.296000e+03  9296.000000    9296.000000
# mean     65.836274    71.006454    2.807022e+06    25.216760     181.497526
# std       6.748544     6.164620    7.295914e+06     4.713049       6.841115
# min      47.000000    48.000000    0.000000e+00    16.000000     155.000000
# 25%      62.000000    67.000000    5.000000e+05    21.000000     177.000000
# 50%      66.000000    71.000000    1.000000e+06    25.000000     182.000000
# 75%      70.000000    75.000000    2.000000e+06    29.000000     186.000000
# max      91.000000    92.000000    1.090000e+08    42.000000     206.000000
#
#        Weight(in kg)   TotalStats    BaseStats  Wage(in Euro)  Release Clause  \
# count    9296.000000  9296.000000  9296.000000    9296.000000    9.296000e+03
# mean       75.194277  1603.815297   357.805077    8650.968158    4.935257e+06
# std         6.960823   270.768892    39.413458   18725.343426    1.391621e+07
# min        53.000000   777.000000   224.000000       0.000000    0.000000e+00
# 25%        70.000000  1472.750000   331.000000    1000.000000    6.740000e+05
# 50%        75.000000  1640.000000   358.000000    3000.000000    1.500000e+06
# 75%        80.000000  1787.000000   385.000000    8000.000000    3.300000e+06
# max       105.000000  2305.000000   502.000000  420000.000000    2.453000e+08
#
#          Joined On  Weak Foot Rating  Skill Moves  International Reputation  \
# count  9296.000000       9296.000000  9296.000000               9296.000000
# mean   2020.352087          2.942233     2.374247                  1.083907
# std       2.079191          0.670438     0.769021                  0.352743
# min    2005.000000          1.000000     1.000000                  1.000000
# 25%    2020.000000          3.000000     2.000000                  1.000000
# 50%    2021.000000          3.000000     2.000000                  1.000000
# 75%    2022.000000          3.000000     3.000000                  1.000000
# max    2022.000000          5.000000     5.000000                  5.000000
#
#        status
# count  9296.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
#            Overall    Potential  Value(in Euro)          Age  Height(in cm)  \
# count  9243.000000  9243.000000    9.243000e+03  9243.000000    9243.000000
# mean     65.867900    71.026939    2.944293e+06    25.264200     181.604457
# std       6.828484     6.221462    7.961528e+06     4.723436       6.875086
# min      47.000000    49.000000    0.000000e+00    16.000000     158.000000
# 25%      62.000000    67.000000    4.750000e+05    22.000000     177.000000
# 50%      66.000000    71.000000    9.750000e+05    25.000000     182.000000
# 75%      70.000000    75.000000    2.000000e+06    29.000000     186.000000
# max      91.000000    95.000000    1.905000e+08    44.000000     203.000000
#
#        Weight(in kg)   TotalStats    BaseStats  Wage(in Euro)  Release Clause  \
# count    9243.000000  9243.000000  9243.000000    9243.000000    9.243000e+03
# mean       75.153413  1600.404090   358.088175    8999.102023    5.228958e+06
# std         7.066586   275.548426    39.844753   20172.437941    1.539416e+07
# min        49.000000   759.000000   226.000000       0.000000    0.000000e+00
# 25%        70.000000  1468.000000   331.000000    1000.000000    6.600000e+05
# 50%        75.000000  1641.000000   359.000000    3000.000000    1.500000e+06
# 75%        80.000000  1784.500000   385.000000    8000.000000    3.400000e+06
# max       104.000000  2312.000000   501.000000  450000.000000    3.667000e+08
#
#          Joined On  Weak Foot Rating  Skill Moves  International Reputation  \
# count  9243.000000       9243.000000  9243.000000               9243.000000
# mean   2020.382884          2.950665     2.358001                  1.088716
# std       2.033159          0.677130     0.775795                  0.364702
# min    2002.000000          1.000000     1.000000                  1.000000
# 25%    2020.000000          3.000000     2.000000                  1.000000
# 50%    2021.000000          3.000000     2.000000                  1.000000
# 75%    2022.000000          3.000000     3.000000                  1.000000
# max    2022.000000          5.000000     5.000000                  5.000000
#
#        status
# count  9243.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0

# %% [markdown]
# <font size = "5">
#
# (f) Create two overlapping histogram plots
#
# <font size = "3">
#
# - This function requires the two datasets you created in (e)
# - Display the distribution of "Age" for "data0" and "data1"
# - Use the "alpha" option to make the graphs semitransparent
# - You will need to add a legend, label the axes, and the title
#
# Note: The goal of this question is to illustrate that random <br>
# assignment produces very similar distributions between two groups

# %%
# Write your own code
list_unique_Ages = pd.unique(Soccer["Age"])

for category_value in list_unique_Ages:
    temporarydataframe = Soccer.query("Age == @category_value")
    plt.hist(temporarydataframe["Age"],alpha = 0.8)

plt.legend(labels = list_unique_Ages)
plt.show()
